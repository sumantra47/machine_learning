# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %% [raw]
# """
# Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
# 61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
# """

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset [wind.csv](https://github.com/guipsamora/pandas_exercises/blob/master/Stats/Wind_Stats/wind.data) from the folder

# %%
pd.read_csv('F:/analytix_labs/2. Pandas Basic Exercises/Exercise Data Files\Pandas Exercise Date Time Operations Files/wind.data')
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
df_wind=pd.read_csv('F:/analytix_labs/2. Pandas Basic Exercises/Exercise Data Files\Pandas Exercise Date Time Operations Files/wind.data')
df_wind.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
df_wind['Date']=df_wind['Yr'].astype(str)+'-'+df_wind['Mo'].astype(str)+'-'+df_wind['Dy'].astype(str)
df_wind.head()
df_wind.Date.unique()
#df_wind.drop(['Yr','Mo','Dy'],axis=1,inplace= True)
# Out:
# array(['61-1-1', '61-1-2', '61-1-3', ..., '78-12-29', '78-12-30',
#        '78-12-31'], dtype=object)

# %%
df_wind.Date=pd.to_datetime(df_wind.Date,format = '%y-%m-%d')
df_wind.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL       Date
# 0  12.58  18.50  15.04 2061-01-01
# 1   9.67  17.54  13.83 2061-01-02
# 2   7.67  12.75  12.71 2061-01-03
# 3   5.88   5.46  10.88 2061-01-04
# 4  10.34  12.92  11.83 2061-01-05

# %% [markdown]
# ### Step 4. Year 2061 is seemingly imporoper. Convert every year which are < 70 to 19XX instead of 20XX.

# %%
#df_wind.Date=df_wind.Yr.apply(lambda x : df_wind.Date +pd.DateOffset(years=-100) if x < 70 else df_wind.Date)

# %%
df_wind.Date=pd.Series(np.where(df_wind.Yr < 70 ,df_wind.Date +pd.DateOffset(years=-100),df_wind.Date))

# %%
df_wind.Date.unique()
# Out:
# array(['1961-01-01T00:00:00.000000000', '1961-01-02T00:00:00.000000000',
#        '1961-01-03T00:00:00.000000000', ...,
#        '1978-12-29T00:00:00.000000000', '1978-12-30T00:00:00.000000000',
#        '1978-12-31T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
df_wind1=df_wind

# %%
df_wind1.set_index('Date',inplace = True)

# %%
#df_wind.Date.unique()

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
df_wind1.shape[0]-df_wind1.count()
# Out:
# Yr     0
# Mo     0
# Dy     0
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
df_wind1.count().sum()
# Out:
# 98579

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
df_wind=df_wind.reset_index()

# %%
df_wind
# Out:
#            Date  Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# 0    1961-01-01  61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67
# 1    1961-01-02  61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50
# 2    1961-01-03  61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25
# 3    1961-01-04  61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63
# 4    1961-01-05  61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92
# ...         ...  ..  ..  ..    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46
# 6570 1978-12-28  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33
# 6571 1978-12-29  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17
# 6572 1978-12-30  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08
# 6573 1978-12-31  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25
#
#         CLA    MUL    CLO    BEL    MAL
# ...

# %%
df_wind_fil=df_wind.drop(columns=['Date','Yr','Dy','Mo'])
df_wind_fil.mean()
# Out:
# RPT    12.362987
# VAL    10.644314
# ROS    11.660526
# KIL     6.306468
# SHA    10.455834
# BIR     7.092254
# DUB     9.797343
# CLA     8.495053
# MUL     8.493590
# CLO     8.707332
# BEL    13.121007
# MAL    15.599079
# dtype: float64

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats=df_wind_fil.agg(['mean','min','max','std'])

# %%
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# mean  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# min    0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# std    5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# mean   9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# min    0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# std    4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats=df_wind_fil.agg(['mean','min','max','std'],axis=1)

# %%
day_stats['Date']=df_wind.Date

# %%
day_stats
# Out:
#            mean   min    max       std       Date
# 0     13.018182  9.29  18.50  2.808875 1961-01-01
# 1     11.336364  6.50  17.54  3.188994 1961-01-02
# 2     11.641818  6.17  18.50  3.681912 1961-01-03
# 3      6.619167  1.79  11.75  3.198126 1961-01-04
# 4     10.630000  6.17  13.33  2.445356 1961-01-05
# ...         ...   ...    ...       ...        ...
# 6569  16.708333  8.08  40.08  7.868076 1978-12-27
# 6570  15.150000  5.00  41.46  9.687857 1978-12-28
# 6571  14.890000  8.71  29.58  5.756836 1978-12-29
# 6572  15.367500  9.13  28.79  5.540437 1978-12-30
# 6573  15.402500  9.59  27.29  5.702483 1978-12-31
#
# [6574 rows x 5 columns]

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
df_wind_jan=df_wind.loc[df_wind.Mo== 1]

# %%
df_wind_jan.mean()
# Out:
# Yr     69.500000
# Mo      1.000000
# Dy     16.000000
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
df_wind_yr=df_wind.groupby('Yr').mean()

# %%
df_wind_yr
# Out:
#           Mo         Dy        RPT        VAL        ROS       KIL        SHA  \
# Yr
# 61  6.526027  15.720548  12.299583  10.351796  11.362369  6.958227  10.881763
# 62  6.526027  15.720548  12.246923  10.110438  11.732712  6.960440  10.657918
# 63  6.526027  15.720548  12.813452  10.836986  12.541151  7.330055  11.724110
# 64  6.513661  15.756831  12.363661  10.920164  12.104372  6.787787  11.454481
# 65  6.526027  15.720548  12.451370  11.075534  11.848767  6.858466  11.024795
# 66  6.526027  15.720548  13.461973  11.557205  12.020630  7.345726  11.805041
# 67  6.526027  15.720548  12.737151  10.990986  11.739397  7.143425  11.630740
# 68  6.513661  15.756831  11.835628  10.468197  11.409754  6.477678  10.760765
# 69  6.526027  15.720548  11.166356   9.723699  10.902000  5.767973   9.873918
# 70  6.526027  15.720548  12.600329  10.726932  11.730247  6.217178  10.567370
# 71  6.526027  15.720548  11.273123   9.095178  11.088329  5.241507   9.440329
# ...

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
df_wind_wk=df_wind.groupby('Mo').mean()

# %%
df_wind_wk
# Out:
#            Yr         Dy        RPT        VAL        ROS       KIL  \
# Mo
# 1   69.500000  16.000000  14.847325  12.914560  13.299624  7.199498
# 2   69.503937  14.614173  13.710906  12.111122  12.879132  6.942411
# 3   69.500000  16.000000  13.158687  11.505842  12.648118  7.265907
# 4   69.500000  15.500000  12.555648  10.429759  12.204815  6.898037
# 5   69.500000  16.000000  11.724032  10.145619  11.550394  6.307487
# 6   69.500000  15.500000  10.451317   8.949704  10.361315  5.652278
# 7   69.500000  16.000000   9.992007   8.357778   9.349642  5.416935
# 8   69.500000  16.000000  10.213411   8.415143   9.993441  5.270681
# 9   69.500000  15.500000  11.458519   9.981002  10.756883  5.615176
# 10  69.500000  16.000000  12.660610  11.010681  11.453943  6.065215
# 11  69.500000  15.500000  13.200722  11.639500  12.293407  6.247611
# 12  69.500000  16.000000  14.446398  12.353602  13.212276  6.829910
#
# ...

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
week_ind=pd.Series((df_wind.index//7)+1)
df_wind['week_ind']=week_ind

# %%
df_wind_week=df_wind.groupby('week_ind').mean()

# %%
df_wind_week
# Out:
#             Yr         Mo         Dy        RPT        VAL        ROS  \
# week_ind
# 1         61.0   1.000000   4.000000  14.124286  12.355000  11.280000
# 2         61.0   1.000000  11.000000  12.314286   8.978571  11.368571
# 3         61.0   1.000000  18.000000  13.554286  10.404286  13.244286
# 4         61.0   1.000000  25.000000  18.410000  13.565714  16.458571
# 5         61.0   1.571429  14.285714  15.965000  16.482857  12.988571
# ...        ...        ...        ...        ...        ...        ...
# 936       78.0  12.000000   6.000000  20.210000  19.018571  17.207143
# 937       78.0  12.000000  13.000000  18.908571  17.454286  16.201429
# 938       78.0  12.000000  20.000000  11.327143   7.662857  12.590000
# 939       78.0  12.000000  27.000000  13.285714  10.118571  13.868571
# 940       78.0  12.000000  31.000000  20.330000  17.410000  27.290000
#
#                 KIL        SHA        BIR        DUB        CLA        MUL  \
# week_ind
# ...

# %% [markdown]
# ### Step 15. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
df_wind_yymm=pd.read_csv('F:/analytix_labs/2. Pandas Basic Exercises/Exercise Data Files\Pandas Exercise Date Time Operations Files/wind.data')

# %%
df_wind_yymm['Date_yymm']=df_wind_yymm['Yr'].astype(str)+'-'+df_wind_yymm['Mo'].astype(str)

# %%
df_wind_yymm.groupby('Date_yymm').mean()
# Out:
#              Yr    Mo    Dy        RPT        VAL        ROS       KIL  \
# Date_yymm
# 61-1       61.0   1.0  16.0  14.841333  11.988333  13.431613  7.736774
# 61-10      61.0  10.0  16.0  14.289667  10.915806  12.236452  8.154839
# 61-11      61.0  11.0  15.5  10.896333   8.592667  11.850333  6.045667
# 61-12      61.0  12.0  16.0  14.973548  11.903871  13.980323  7.073871
# 61-2       61.0   2.0  14.5  16.269286  14.975357  14.441481  9.230741
# ...         ...   ...   ...        ...        ...        ...       ...
# 78-5       78.0   5.0  16.0   8.270645   7.226774   6.901613  3.740645
# 78-6       78.0   6.0  15.5  11.386667   9.474333  10.253333  6.053000
# 78-7       78.0   7.0  16.0  12.820000   9.750968   9.910323  6.483871
# 78-8       78.0   8.0  16.0   9.645161   8.259355   9.032258  4.502903
# 78-9       78.0   9.0  15.5  10.913667  10.895000  10.635000  5.725000
#
#                  SHA        BIR        DUB        CLA        MUL        CLO  \
# Date_yymm
# ...

# %% [markdown]
# ### Step 16. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
df_wind.head(10)
# Out:
#         Date  Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB  \
# 0 1961-01-01  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67
# 1 1961-01-02  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50
# 2 1961-01-03  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25
# 3 1961-01-04  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63
# 4 1961-01-05  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92
# 5 1961-01-06  61   1   6  13.21   8.12   9.96   6.67   5.37  4.50  10.67
# 6 1961-01-07  61   1   7  13.50  14.29   9.50   4.96  12.29  8.33   9.17
# 7 1961-01-08  61   1   8  10.96   9.75   7.62   5.91   9.62  7.29  14.29
# 8 1961-01-09  61   1   9  12.58  10.83  10.00   4.75  10.37  6.79   8.04
# 9 1961-01-10  61   1  10  13.37  11.12  19.50   8.33   9.71  6.54  11.42
#
#      CLA    MUL    CLO    BEL    MAL  week_ind
# 0  10.25  10.83  12.58  18.50  15.04         1
# 1  10.04   9.79   9.67  17.54  13.83         1
# ...

# %%
df_wind52w=df_wind[1:df_wind.shape[0]].drop(columns='week_ind').reset_index(drop=True)

# %%
df_wind52w['week_ind']=pd.Series((df_wind52w.index//7)+1)

# %%
df_wind52w.loc[week_ind<=52,['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']].groupby(week_ind).agg(['mean','min','max','std'],axis=1)
# Out:
#           RPT                                VAL                          \
#          mean    min    max       std       mean    min    max       std
# 1   13.541429  10.58  18.50  2.631321  11.486667   6.63  16.88  3.949525
# 2   12.468571   9.04  19.75  3.555392   8.967143   3.54  12.08  3.148945
# 3   13.204286   4.92  19.83  5.337402   9.862857   3.42  14.37  3.837785
# 4   19.880000  13.62  25.04  4.619061  16.141429   9.96  23.91  5.170224
# 5   16.827143  10.58  24.21  5.251408  15.460000   9.46  24.21  5.187395
# 6   19.684286  16.00  24.54  3.587677  16.417143  11.54  21.42  3.608373
# 7   15.130000   6.04  22.50  5.064609  15.091429  11.63  20.17  3.575012
# 8   15.221429   7.79  25.80  7.020716  13.625714   7.08  21.50  5.147348
# 9   12.101429  10.96  13.33  0.997721  12.951429   8.83  17.00  2.851955
# 10   9.376667   4.88  14.79  3.732263  11.578571   8.08  16.96  3.230167
# 11  11.911429   4.92  16.88  3.860036  13.501429   9.46  15.54  2.352867
# ...
